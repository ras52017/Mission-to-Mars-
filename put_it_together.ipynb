# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# Set up Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

url = 'http://quotes.toscrape.com/'
browser.visit(url)
html = browser.html
quote_soup = soup(html, 'html.parser')

# %%
for x in range(1, 6):
   html = browser.html
   quote_soup = soup(html, 'html.parser')
   quotes = quote_soup.find_all('div','span', class_='quote')
   for quote in quotes:
      print('page:', x, '----------')
      print(quote.text)
   browser.links.find_by_partial_text('Next').click()
# Out:
# page: 1 ----------
#
# “The truth." Dumbledore sighed. "It is a beautiful and terrible thing, and should therefore be treated with great caution.”
# by J.K. Rowling
# (about)
#
#
#             Tags:
#
# truth
#
#
# page: 1 ----------
#
# “I'm the one that's got to die when it's time for me to die, so let me live my life the way I want to.”
# by Jimi Hendrix
# (about)
#
#
#             Tags:
#
# death
# life
#
#
# page: 1 ----------
#
# “To die will be an awfully big adventure.”
# by J.M. Barrie
# (about)
#
#
#             Tags:
#
# adventure
# love
#
#
# page: 1 ----------
#
# “It takes courage to grow up and become who you really are.”
# by E.E. Cummings
# (about)
#
#
#             Tags:
#
# courage
#
#
# page: 1 ----------
#
# “But better to get hurt by the truth than comforted with a lie.”
# by Khaled Hosseini
# (about)
#
#
#             Tags:
#
# life
#
#
# page: 1 ----------
#
# “You never really understand a person until you consider things from his point of view... Until you climb inside of his skin and walk around in it.”
# by Harper Lee
# (about)
#
#
#             Tags:
#
# better-life-empathy
#
#
# page: 1 ----------
#
# “You have to write the book that wants to be written. And if the book will be too difficult for grown-ups, then you write it for children.”
# by Madeleine L'Engle
# (about)
#
#
#             Tags:
#
# books
# children
# difficult
# grown-ups
# write
# writers
# writing
#
#
# page: 1 ----------
#
# “Never tell the truth to people who are not worthy of it.”
# by Mark Twain
# (about)
#
#
#             Tags:
#
# truth
#
#
# page: 1 ----------
#
# “A person's a person, no matter how small.”
# by Dr. Seuss
# (about)
#
#
#             Tags:
#
# inspirational
#
#
# page: 1 ----------
#
# “... a mind needs books as a sword needs a whetstone, if it is to keep its edge.”
# by George R.R. Martin
# (about)
#
#
#             Tags:
#
# books
# mind
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\ras52\anaconda3\envs\PythonData\lib\site-packages\splinter\element_list.py:40, in ElementList.__getitem__(self, index)
#      39 try:
# ---> 40     return self._container[index]
#      41 except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ElementDoesNotExist                       Traceback (most recent call last)
# d:\WASHU DATA Analytics\WUSTL-VIRT-DATA-PT-08-2022-U-B-main\11-Web-Scraping\New folder\put_it_together.ipynb Cell 2 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/WASHU%20DATA%20Analytics/WUSTL-VIRT-DATA-PT-08-2022-U-B-main/11-Web-Scraping/New%20folder/put_it_together.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a>    print('page:', x, '----------')
#       <a href='vscode-notebook-cell:/d%3A/WASHU%20DATA%20Analytics/WUSTL-VIRT-DATA-PT-08-2022-U-B-main/11-Web-Scraping/New%20folder/put_it_together.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a>    print(quote.text)
# ----> <a href='vscode-notebook-cell:/d%3A/WASHU%20DATA%20Analytics/WUSTL-VIRT-DATA-PT-08-2022-U-B-main/11-Web-Scraping/New%20folder/put_it_together.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> browser.links.find_by_partial_text('Next').click()
#
# File c:\Users\ras52\anaconda3\envs\PythonData\lib\site-packages\splinter\element_list.py:78, in ElementList.__getattr__(self, name)
#      76 def __getattr__(self, name):
#      77     try:
# ---> 78         return getattr(self.first, name)
#      79     except AttributeError:
#      80         try:
#
# File c:\Users\ras52\anaconda3\envs\PythonData\lib\site-packages\splinter\element_list.py:56, in ElementList.first(self)
#      48 @property
#      49 def first(self):
#      50     """An alias to the first element of the list.
#      51
#      52     Example:
#      53
#      54         >>> assert element_list[0] == element_list.first
#      55     """
# ---> 56     return self[0]
#
# File c:\Users\ras52\anaconda3\envs\PythonData\lib\site-packages\splinter\element_list.py:42, in ElementList.__getitem__(self, index)
#      40     return self._container[index]
#      41 except IndexError:
# ---> 42     raise ElementDoesNotExist(
#      43         u'no elements could be found with {0} "{1}"'.format(
#      44             self.find_by, self.query
#      45         )
#      46     )
#
# ElementDoesNotExist: no elements could be found with link by partial text "Next"

# %%
browser.quit()
